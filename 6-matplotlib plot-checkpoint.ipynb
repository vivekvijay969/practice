# %%
import pandas as pd
df= pd.DataFrame({"temp":[23,34,45],"rank":[1, 2,3]})
df
# Out:
#    temp  rank
# 0    23     1
# 1    34     2
# 2    45     3

# %%
import matplotlib.pyplot as mt
mt.plot(df)

# %% [markdown]
# x= [2,3,4,5,6,7,8]
# y= [23,45,43,67,43]
# mpl.plot(x,y)

# %%
x= [2,3,4,5,6,7,8] 
y= [23,45,43,67,43,3,4] 
mt.plot(x,y, color= "green", linewidth=4, linestyle= 'dashdot')
